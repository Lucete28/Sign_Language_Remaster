# %%
import numpy as np
data = np.load(r'C:\Users\oem\Desktop\jhy\dataset\okay\seq_1706512983_1946.npy')
data.shape
# Out:
# (1946, 30, 156)

# %%
data[0].shape
# Out:
# (30, 156)

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time
from tqdm import tqdm
# 넘파이 배열 생성 (예제용)
data = np.random.random((100, 30, 156))

# 반복 횟수
num_iterations = data.shape[0]

for i in tqdm(range(num_iterations)):
    # 넘파이 배열 선택
    d1 = data[i]

    # 시각화
    plt.imshow(d1, cmap='viridis')
    plt.colorbar()
    plt.title('Visualization of 30x156 Numpy Array')
    plt.show()

    # 출력 지우기
    time.sleep(1)
    clear_output(wait=True)
# Out:
#  60%|██████    | 60/100 [01:13<00:49,  1.23s/it]
#  60%|██████    | 60/100 [01:14<00:49,  1.24s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 23
#      20 plt.show()
#      22 # 출력 지우기
# ---> 23 time.sleep(1)
#      24 clear_output(wait=True)
#
# KeyboardInterrupt:

# %%
50 * 7
# Out:
# 350

# %%
import numpy as np
import matplotlib.pyplot as plt

# 예제용 100개의 30x156 배열 생성
# data2 = np.random.random((100, 30, 156))

# 이전 배열과의 유사도를 저장할 리스트
similarities = []
data2 = data
# 이전 배열 초기화
prev_array = data2[0].flatten()

# 반복문으로 각 배열과의 유사도 계산 및 시각화
for i in range(1, len(data2)):
    current_array = data2[i].flatten()

    # 코사인 유사도 계산
    cosine_similarity = np.dot(prev_array, current_array) / (np.linalg.norm(prev_array) * np.linalg.norm(current_array))

    # 유사도 저장
    similarities.append(cosine_similarity)

    # 히트맵으로 시각화

    # 현재 배열을 이전 배열로 설정
    prev_array = current_array

plt.plot(range(1, i+1), similarities, marker='o')
plt.title('Cosine Similarity with Previous Array')
plt.xlabel('Iteration')
plt.ylabel('Similarity')
plt.grid(True)
plt.show()

# %%
128 * 8
# Out:
# 1024

# %%
500개 -- 128gb
4000개 -- 1024gb

# %%
similarities.count(max(similarities))
# Out:
# 1

# %%
max(similarities)
# Out:
# 0.9998721772891485

# %%
sum(1 for x in similarities if x >= 0.999)
# Out:
# 181

# %%
############## 중복 영어이름 검사기
import json

# Specify the file path
file_path = r'C:\Users\oem\Desktop\jhy\signlanguage\Sign_Language_Remaster\logs\api_log.json'

# Open the file and load JSON data
with open(file_path, 'r') as file:
    jd = json.load(file)

li = []
for j in jd['Daily']:
    for i in jd['Daily'][j]:
        if i in li:
            print(f'{j}페이지에 {i}')
        li.append(i)
# Out:
# 3페이지에 limp
# 12페이지에 Rule
# 27페이지에 Public
# 33페이지에 Defender
# 35페이지에 shed
# 39페이지에 Job
# 44페이지에 Poverty
# 46페이지에 theory
